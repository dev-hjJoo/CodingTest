# %% [markdown]
# ### 001. 출력하기01 (6001)

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ### 002. 출력하기02 (6002)

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### 003. 출력하기03 (6003)

# %%
print("Hello") 
print("World")
# Out:
# Hello
# World

# %% [markdown]
# ### 004. 출력하기04 (6004)

# %%
print("'Hello'")
# Out:
# 'Hello'

# %% [markdown]
# ### 005. 출력하기05 (6005)

# %%
print('"Hello World"')
# Out:
# "Hello World"

# %% [markdown]
# ### 006. 출력하기06 (6006)

# %%
print("\"!@#$%^&*()'")
# Out:
# "!@#$%^&*()'

# %% [markdown]
# ### 007. 출력하기07 (6007)

# %%
print("\"C:\\Download\\'hello'.py\"")
# Out:
# "C:\Download\'hello'.py"

# %% [markdown]
# ### 008. 출력하기08 (6008)

# %%
print('print("Hello\\nWorld")')
# Out:
# print("Hello\nWorld")

# %% [markdown]
# ### 009. 문자 입력받아 그대로 출력하기 (6009)

# %%
c = input()
print(c)
# Out:
#  c
# c

# %% [markdown]
# ### 010. 정수 입력받아 int로 변환하여 출력하기 (6010)

# %%
n = input()
print(int(n))
# Out:
#  3
# 3

# %% [markdown]
# ### 011. 실수 입력받아 변환하여 출력하기 (6011)

# %%
f = input()
print(float(f))
# Out:
#  1.414213
# 1.414213

# %% [markdown]
# ### 012. 정수 2개 입력받아 int로 변환하여 출력하기 (6012)

# %%
a = input()
b = input()
a, b = int(a), int(b)

print(a)
print(b)
# Out:
#  1
#  2
# 1
# 2

# %% [markdown]
# ### 013. 문자 2개 입력받아 순서 바꾸어 출력하기 (6013)

# %%
a = input()
b = input()

print(b)
print(a)
# Out:
#  a
#  b
# b
# a

# %% [markdown]
# ### 014. 실수 1개 입력 받아 3번 출력하기 (6014)

# %%
f = input()
f = float(f)

output = f"{f}\n"
print(output*3)
# Out:
#  0.1
# 0.1
# 0.1
# 0.1

# %% [markdown]
# ### 015. 정수 2개 입력 받아 그대로 출력하기2 (6015)

# %%
a, b = input().split()
a, b = int(a), int(b)

print(a)
print(b)
# Out:
#  1 3
# 1
# 3
